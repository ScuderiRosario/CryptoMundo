# %% [markdown]
# # CryptoMundo

# %% [markdown]
# *CryptoMundo is a simple and easy tool to analyze cryptocurrency data in real time which provides a simple and informative dashboard.*

# %% [markdown]
# ### Why?

# %% [markdown]
# ![1](https://www.memecreator.org/static/images/memes/4158660.jpg)

# %% [markdown]
# ### Global Aggregation: All you need in one place

# %% [markdown]
# ![dashboard.png](attachment:dashboard.png)

# %% [markdown]
# ### How it works?

# %% [markdown]
# ### Problem . . .

# %% [markdown]
# ![2](https://th.bing.com/th/id/OIP.Z5Y92ZW0gIJlDl_aM23PEwHaCe?pid=ImgDet&rs=1)

# %% [markdown]
# ### All crypto are different!

# %% [markdown]
# ### What is the solution?

# %% [markdown]
# ### A constantly updated model for each crypto!

# %% [markdown]
# ### How?

# %% [markdown]
# ![3](https://infinitelambda.com/wp-content/uploads/2021/01/Apache-Airflow-logo-1536x594.png)

# %% [markdown]
# ![Airflow1.png](attachment:Airflow1.png)

# %% [markdown]
# ![Airflow%202.png](attachment:Airflow%202.png)

# %% [markdown]
# ![SegmentLocal](https://static.goodwood.com/lgrrc/2015/11/Ariel_Atom_Insane_Speed_Machine_HQ_Top_Gear_Series_5_BBC.gif "segment")

# %% [markdown]
# ![4](https://i.ytimg.com/vi/w5M46Vc6p40/maxresdefault.jpg)

# %% [markdown]
# ![Airflow3.png](attachment:Airflow3.png)

# %% [markdown]
# ### To the moon!

# %% [markdown]
# ![5](https://th.bing.com/th/id/OIP.6KZWwdXUIS2j_D01OMcwGAHaEJ?pid=ImgDet&rs=1)

# %% [markdown]
# ![5](https://th.bing.com/th/id/OIP.0RZe5Ny0-fF5Ew7m7r1T8wAAAA?pid=ImgDet&rs=1)

# %% [markdown]
# ### WorkFlow

# %% [markdown]
# ![progettotap.jpg](attachment:progettotap.jpg)
